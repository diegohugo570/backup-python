# %% [markdown]
# <a href="https://colab.research.google.com/github/diegohugo570/backup-python/blob/main/01_Curso_Python_M%C3%B3dulo_1_Forma%C3%A7%C3%A3o_Engenheiro_de_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Módulo 1: Fundamentos da Linguagem Python**
#
# Link do curso: [clique aqui](https://dascia.academy/)
#
# > **Objetivo:** Dominar a sintaxe essencial, tipos de dados e lógica básica necessária para manipular textos (prompts) e números (métricas) em projetos de Inteligência Artificial.
#
# ---

# %% [markdown]
# ## **Aula 2: O Primeiro Contato e Saída de Dados**
#
# Para que um software de IA seja útil, ele precisa se comunicar conosco. No Python, a forma mais primitiva e essencial de comunicação é a função `print()`.
#
# Pense no `print` como o comando que diz ao computador: **"Mostre isso na tela para o humano agora."** Sem ele, o Python faria todos os cálculos na memória silenciosamente e o programa terminaria sem você ver nada.
#
# Em Python, textos devem ser sempre delimitados por aspas (simples ou duplas). Isso avisa ao interpretador onde o texto começa e onde termina.

# %%
# O comando print() envia dados para a saída padrão (console/terminal).


# Simulação de um chat entre Humano e AI

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 1)**
#
# **Exercício 1.1: O Status do Sistema**
#
# Crie um código que exiba na tela três linhas simulando a inicialização de um modelo de IA. As mensagens devem ser:
#
# 1. "Iniciando sistema..."
# 2. "Carregando modelo de linguagem..."
# 3. "Sistema online e pronto!"

# %%
# Escreva seu código aqui

# %% [markdown]
# **Exercício 1.2: Identificação**
#
# Escreva um código que imprima o nome do curso na primeira linha e o seu nome (como aluno) na segunda linha.

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **Aula 3: Variáveis e Tipos de Dados**
#
# Na programação, raramente trabalhamos com valores fixos. Precisamos de "caixas" para guardar informações que podem mudar (o nome de um usuário, o preço de um token, a resposta de uma IA).
#
# Essas caixas são as **Variáveis**. Elas são espaços na memória que armazenam uma informação.
#
# Em Python, você cria uma variável dando um nome a ela e usando o sinal de igual `=` (operador de atribuição) para guardar um valor.

# %% [markdown]
# ### **2.1 Strings (Textos)**
#
# Strings (`str`) são sequências de caracteres. São a matéria-prima dos LLMs (Large Language Models). Existem três formas principais de declarar strings no Python, e cada uma tem uma utilidade específica.
#
# * **Aspas Simples ou Duplas:** Para textos curtos, de uma linha.
# * **Aspas Triplas:** Para textos longos ou multilinhas (muito usado em prompts complexos).

# %%
# Aula 2 - Strings

# Aspas simples: O padrão mais comum para palavras soltas ou frases curtas.


# Aspas duplas: Funciona exatamente igual. Útil se o seu texto já contém uma aspa simples dentro (ex: "Don't").


# Aspas triplas: Permitem criar strings exatamente como foram digitadas.


# Exibindo resultado

# %% [markdown]
# As aspas triplas têm um superpoder: elas respeitam as quebras de linha. Isso é fundamental quando você está escrevendo um System Prompt longo para um agente de IA e quer manter a formatação visual organizada.

# %%
# Aspas triplas para múltiplas linhas
# O Python vai preservar cada "Enter" que você deu dentro das aspas.

# Variável com aspas triplas em múltiplas linhas


# Exibindo nome com aspas triplas

# %% [markdown]
# ### **2.2 Números e Booleanos**
#
# Além de texto, precisamos lidar com matemática e lógica.
#
# * **Inteiros (`int`):** Números sem casa decimal. Usados para contagens (ex: número de tokens, número de iterações). Note que podemos usar `_` para separar milhares visualmente (ex: `20_000`), o Python ignora o sublinhado.
# * **Floats (`float`):** Números com ponto flutuante (decimais). Usados para precisão (ex: temperatura do modelo, custo em dólares). **Atenção:** Use ponto `.`, e não vírgula.
# * **Booleanos (`bool`):** O tipo mais simples. Só existem dois valores: `True` (Verdadeiro) ou `False` (Falso). São a base das tomadas de decisão (se `True`, faça isso...).

# %%
# Inteiros - Números inteiros (o _ é ignorado, serve apenas para leitura humana)


# Float - Números decimais (atenção ao ponto, não vírgula!)


# Boolean - Verdadeiro ou Falso (Sempre com primeira letra maiúscula em Python)


# Exibindo resultados

# %% [markdown]
# ### **2.3 Conversão de Tipos (Casting)**
#
# Muitas vezes recebemos um dado em um formato errado. Por exemplo, todo `input` do usuário (*veremos sobre o `input` na próxima aula*) vem como texto (String), mesmo que ele digite um número. Se tentarmos somar o texto "10" com o número 5, dará erro.
#
# O **Casting** é o ato de forçar um dado a mudar de tipo.
#
# * `int()`: Tenta transformar em inteiro.
# * `str()`: Transforma qualquer coisa em texto.
# * `float()`: Tenta transformar em decimal.
# * `bool()`: Verifica a veracidade (Strings vazias ou 0 viram False, o resto vira True).

# %%
# Conversão de tipos

# String para inteiro


# Float para string (útil para concatenar em mensagens)


# Float para inteiro (CUIDADO: isso corta a parte decimal, não arredonda!)

# %% [markdown]
# A conversão para Booleano é curiosa e muito usada em validações, que veremos mais a frente no curso.
#
# * A string "False" convertida para `bool` vira `True`? **Sim!** Porque é uma string não vazia.
# * Para o Python, apenas strings vazias `""`, o número `0` ou `None` são convertidos para `False`. Todo o resto é `True`.

# %%
# Booleano para string


# Strings para booleano
# Cuidado: Qualquer string não vazia vira True


# String vazia


# Floats para booleano
# Qualquer número diferente de 0.0 é True

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 2)**
#
# **Exercício 2.1: A Ficha do Modelo**
#
# Declare variáveis para armazenar as seguintes informações de um modelo de IA fictício:
#
# * Nome do modelo (String)
# * Tamanho da janela de contexto (Inteiro)
# * Custo por 1k tokens (Float)
# * Está ativo? (Booleano)
# Ao final, imprima o tipo de cada variável usando `type()`.

# %%
# Escreva seu código aqui

# %% [markdown]
# **Exercício 2.2: O Conversor de Dados**
#
# Você recebeu o valor `"1500.90"` como texto de um formulário.
#
# 1. Converta esse texto para `float`.
# 2. Converta o resultado float para `int`.
# 3. Imprima os dois resultados.

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **Aula 4: Interação e Manipulação de Texto**
#
# Agora vamos tornar nossos scripts dinâmicos. A função `input()` pausa a execução do programa e espera o usuário digitar algo e apertar Enter.
#
# **Ponto crucial:** O `input()` **sempre** retorna uma **string**. Mesmo que você digite "100", o Python lerá "100" (texto).
#
# Além disso, apresentamos a **f-string** (Formatted String). Colocando um `f` antes das aspas, você pode injetar variáveis diretamente no texto usando `{chaves}`. Isso é a ferramenta número 1 para criar prompts dinâmicos.

# %%
# Aula 3 - Recebendo input e criando templates

# Pedindo o nome do usuário


# F-strings: A melhor forma de inserir variáveis dentro de textos (prompt personalizável)

# %% [markdown]
# ### **Métodos de Strings (Limpeza de Dados)**
#
# Na engenharia de dados e IA, raramente o dado chega limpo. O usuário digita espaços extras, usa maiúsculas aleatórias, etc. O Python possui "métodos" (funções atreladas ao objeto) para tratar isso.
#
# * `.strip()`: Remove espaços inúteis no início e fim. Vital para limpar inputs.
# * `.upper()` / `.lower()`: Normalização de texto.
# * `.replace(velho, novo)`: Substituição de trechos.

# %%
# Métodos de manipulação

# Imagine que o usuário digitou "  olá  "
prompt_sujo = "   Olá Mundo   "

# Limpar espaços em branco das pontas


# Maiúsculas e Minúsculas


# Substituição (Muito útil para templates de prompt)

# %% [markdown]
# Existem caracteres especiais chamados "Escape Characters". Eles começam com a barra invertida `\`.
#
# * `\n`: New Line (Quebra de linha).
# * `\t`: Tab (Tabulação/Identação).
# E a função `len()` serve para contar o tamanho (length) da string, muito útil para estimar contagem de tokens.

# %%
# Caracteres de escape e contagem


# Comprimento da string (contando espaços e pontuação)

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 3)**
#
# **Exercício 3.1: O Gerador de E-mail**
#
# Peça ao usuário para digitar o `primeiro_nome` e o `sobrenome`.
# Use f-strings para gerar um email no formato `primeiro_nome.sobrenome@empresa.com`. Garanta que o email seja exibido todo em letras minúsculas, mesmo que o usuário digite maiúsculas.

# %%
# Escreva seu código aqui

# %% [markdown]
# **Exercício 3.2: Limpeza de Dataset**
#
# Dada a frase suja: `"   Python é INCRÍVEL!!!   "`.
#
# 1. Remova os espaços extras das pontas.
# 2. Substitua "INCRÍVEL" por "poderoso".
# 3. Imprima o resultado final.

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **Aula 5: Operadores Aritméticos e Lógicos**
#
# Computadores são, na essência, calculadoras gigantes. Para Engenharia de IA, usamos matemática para calcular custos, tokens e dimensões de vetores.

# %% [markdown]
# ### **4.1 Operadores Aritméticos**
#
# A maioria você já conhece da escola, mas preste atenção na **Divisão Inteira (`//`)** e no **Módulo (`%`)**.
#
# * `//`: Divide e joga fora a parte decimal (arredonda para baixo).
# * `%`: Retorna o que *sobrou* da divisão. Útil para saber se um número é par (resto 0) ou para criar ciclos.

# %%
# Aula 4 - Matemática

# Adição, Subtração e Multiplicação


# Divisões (normal, inteira e resto)


# Potência (Exponenciação)
# Atenção: em Python é ** e não ^

# %% [markdown]
# ### **4.2 Operadores Lógicos (Comparação)**
#
# Estes operadores não retornam números, retornam **Booleanos** (`True` ou `False`). Eles são a base da lógica de programação ("Se A for maior que B, então...").
#
# * `==`: Igualdade (Cuidado: `=` é atribuição, `==` é comparação).
# * `!=`: Diferente.
# * `>=`, `<=`: Maior/Menor ou igual.
# * `not`: Inverte a lógica (O que é True vira False).

# %%
# Operadores Lógicos

# Igualdade e Diferença


# Comparações (maior, menor ou igual)


# Negação (Inversão)

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 4)**
#
# **Exercício 4.1: Calculadora de Tokens (Estimativa)**
#
# Uma regra comum é que 1000 tokens custam cerca de $0.002.
# Crie um código que tenha uma variável `qtd_tokens = 5500`. Calcule e imprima o custo total dessa requisição.

# %%
# Escreva seu código aqui

# %% [markdown]
# **Exercício 4.2: Validador de Texto**
#
# Crie uma variável com um texto qualquer. Verifique se o tamanho desse texto (len) é maior que 10 caracteres. O programa deve imprimir apenas `True` ou `False`.

# %%
# Escreva seu código aqui

# %% [markdown]
# ## **🚀 Próximo Passo: Projeto no Cursor**
#
# Parabéns! Você dominou os blocos fundamentais da construção de scripts: variáveis, textos, matemática e lógica booleana.
#
# Aqui no Colab, nós validamos a lógica matemática e a formatação do texto. Mas softwares reais não vivem em notebooks.
#
# **Agora vamos para a IDE Cursor construir o "Prompt Packer".**
#
# Lá, você transformará esse conhecimento em um **software de verdade** que roda no terminal. Você vai aplicar:
#
# 1. **Interatividade Real:** Usar `input()` para capturar dados do usuário na linha de comando.
# 2. **Lógica de Negócio:** Implementar a validação de tamanho do prompt (f-strings + matemática).
# 3. **Versionamento:** O passo mais importante de um engenheiro profissional — salvar seu código na nuvem usando **Git e GitHub**.
#
# Vá para o próximo vídeo/módulo na plataforma para iniciar o projeto!
