# %% [markdown]
# <a href="https://colab.research.google.com/github/diegohugo570/backup-python/blob/main/03_Curso_Python_M%C3%B3dulo_3_Forma%C3%A7%C3%A3o_Engenheiro_de_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Módulo 3: Profissionalização (Funções, Módulos & Gestão de Dependências)**
#
# Link do curso: [clique aqui](https://dascia.academy/)
#
# > **Objetivo:** Transformar scripts soltos em arquitetura de software robusta. Vamos aprender a isolar lógicas em **funções**, tratar **erros** para que o sistema não caia e gerenciar **bibliotecas externas** como profissionais.

# %% [markdown]
# ---
#
# ## **Aula 1: Funções, Decoradores e o Princípio DRY**
#
# Até agora, copiamos e colamos código. Isso viola o mandamento sagrado da programação: **DRY (Don't Repeat Yourself)**.

# %% [markdown]
# ### **1.1 Funções e Type Hinting**
#
# Uma função é uma "minifábrica": recebe matéria-prima (argumentos), processa e entrega um produto (retorno).
# Em Engenharia de IA, usamos **Type Hinting** (`: int`, `-> str`) não porque o Python obriga, mas porque ajuda o editor (e a IA do Cursor) a entender o que entra e o que sai, evitando bugs silenciosos.

# %%
# Aula 1 - Funções e DRY

# JEITO RUIM (Repetitivo e difícil de manter)
# Condicionais com o nome do modelo

# %%
# JEITO BOM com funções (Encapsulado e Tipado)


# Chamando a função

# %% [markdown]
# ### **1.2 Funções Lambda (Anônimas)**
#
# São funções de uma linha só, usadas "na hora" e depois descartadas. Muito comuns dentro de pipelines de dados (como no `map` e `filter` que vimos antes).

# %%
# Lambda: lambda entrada: saida

# %% [markdown]
# ### **1.3 Decoradores (`@decorator`)**
#
# Este é um conceito avançado, mas vital. Decoradores são "embalagens" que colocamos em volta de uma função para adicionar superpoderes a ela (como logar execução, cronometrar tempo ou verificar autenticação) sem mudar o código original da função.
#
# * Frameworks como **FastAPI** e **LangChain** são construídos inteiramente baseados em decoradores.

# %%
# Decoradores (Middleware)


# Aplicando o decorador com o "sintax sugar" @


# Ao chamar a soma, o log acontece automaticamente!

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 1)**
#
# **Exercício 1.1: O Limpador de Prompts**
#
# Crie uma função chamada `limpar_prompt` que recebe uma string suja e um booleano `remover_numeros`.
#
# * A função deve sempre fazer `strip()` e `lower()`.
# * Se `remover_numeros` for True, ela deve remover dígitos da string (dica: use `.replace()` ou pesquise sobre o método `.isdigit()` em loop).
# * Use Type Hinting.

# %%
# Escreva seu código aqui

# %% [markdown]
# **Exercício 1.2: Decorador de Retry**
#
# (Desafio) Em IA, chamadas de API falham. Crie um decorador simples que, antes de executar a função, imprima "Tentativa 1...". Execute a função e, depois, imprima "Sucesso!". Aplique em uma função que apenas imprime "Conectando ao servidor...".

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **Aula 2: Tratamento de Erros e Exceções**
#
# O "Caminho Feliz" (Happy Path) é quando tudo funciona. Mas a internet cai, a API key expira, o arquivo não existe. Se você não tratar esses erros, seu script **quebra** e para de rodar.
#
# Usamos o bloco `try...except` para "capturar" o erro e decidir o que fazer, em vez de deixar o programa morrer.

# %%
# Forçando uma divisão por zero e tentando executar


# Erro de valor


# Erro de divisão por zero


# Erro genérico


# Finalmente...

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 2)**
#
# **Exercício 2.1: Parse Seguro de JSON**
#
# LLMs frequentemente retornam JSONs quebrados. Use o código comentado com `json.loads('{"nome": "GPT"')` (note que falta fechar a chave) para tentar ler um JSON e use `try/except` para capturar o erro (também comentado) `json.JSONDecodeError`.
#
# Você deve imprimir uma mensagem amigável "Falha ao ler JSON da IA".

# %%
# Escreva seu código aqui
import json

# json.loads('{"nome": "GPT"')
# json.JSONDecodeError

# %% [markdown]
# **Exercício 2.2: Validador de API Key**
#
# Crie uma função que recebe uma chave de API. Se a chave não começar com "sk-", levante um `ValueError`. Envolva a chamada da função num try/catch.

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **Aula 3: Gestão de Dependências (Pip vs Poetry)**
#
# Nenhum engenheiro reescreve a roda. Nós importamos rodas prontas.
# O Python tem um repositório gigante de códigos prontos chamado **PyPI**.

# %% [markdown]
# ### **O Jeito "Cru" (Pip)**
#
# No Colab, usamos o `!pip install`. Ele baixa o pacote e joga no ambiente global. Isso funciona, mas em projetos grandes cria o "Inferno de Dependências" (versões conflitando).
#
# ### **O Jeito Profissional (Poetry)**
#
# No projeto final (no Cursor), usaremos o **Poetry**. Ele cria uma "bolha" isolada (ambiente virtual) para cada projeto e trava as versões exatas num arquivo de segurança (`poetry.lock`).
#
# Vamos testar instalando o **NumPy** (que usaremos nos próximos módulos).

# %%
# Instalando biblioteca externa no ambiente do Colab
# !pip install numpy

# Importando e usando
import numpy as np

# Criando uma matriz de zeros (3 linhas, 2 colunas)
# Isso seria complexo fazer com listas puras, o Numpy faz em 1 linha
matriz = np.zeros((3, 2))

print("Matriz NumPy criada:")
print(matriz)

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 3)**
#
# **Exercício 3.1: NumPy Básico**
#
# Importe numpy. Crie uma matriz 5x6 apenas com uns (1).

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **Aula 4: Modularização (Imports)**
#
# Um arquivo `main.py` com 2000 linhas é inaceitável. Profissionais quebram o código em **Módulos**.
#
# No Colab, como não temos sistema de arquivos fácil, usaremos um "truque" (`%%writefile`) para criar um arquivo `.py` simulado e demonstrar como o `import` funciona.

# %%
# Criando um arquivo chamado 'minha_lib.py' dentro do Colab
# %%writefile minha_lib.py

def calcular_tokens_simples(texto: str) -> int:
    """Estima tokens dividindo caracteres por 4."""
    return len(texto) // 4

# %% [markdown]
# Agora que o arquivo existe "no disco" do Colab, podemos importá-lo como se fosse uma biblioteca nativa.

# %%
# Aula 4 - Modularização

# Importando do arquivo que acabamos de criar
from minha_lib import calcular_tokens_simples

texto = "Engenharia de IA com Python"
qtd = calcular_tokens_simples(texto)

print(f"Tokens estimados via módulo externo: {qtd}")

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 4)**
#
# **Exercício 4.1: Criando Módulo de Config**
#
# 1. Use `%%writefile config.py` para criar um arquivo com uma variável `API_KEY = "sk-123456"`.
# 2. Em outra célula, faça `from config import API_KEY`.
# 3. Crie uma função que receba uma chave API e imprima a chave mascarada (só os 2 primeiros caracteres visíveis), o restante dos caracteres deve ser *****.

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **🚀 Próximo Passo: Projeto no Cursor**
#
# Agora temos todas as ferramentas de um Engenheiro de Software: **Funções** para lógica, **Try/Except** para segurança, **Bibliotecas** para poder e **Módulos** para organização.
#
# **Vamos para a IDE Cursor construir a "Token Cost Calculator".**
#
# Neste projeto, você enfrentará um desafio lógico real:
#
# * Calcular o custo de uma conversa que *cresce* a cada mensagem (Janela de Contexto).
# * Você não vai calcular apenas `input + output`.
# * Você vai calcular `(msg1) + (msg1 + resp1 + msg2) + ...`.
# * E tudo isso usando **Poetry** para instalar dependências e separando a lógica matemática (`calculadora.py`) da interface do usuário (`main.py`).
#
# Essa separação é o que distingue um script amador de uma biblioteca profissional. Te vejo lá!
