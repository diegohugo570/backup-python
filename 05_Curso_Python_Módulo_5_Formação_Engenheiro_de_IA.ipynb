# %% [markdown]
# <a href="https://colab.research.google.com/github/diegohugo570/backup-python/blob/main/05_Curso_Python_M%C3%B3dulo_5_Forma%C3%A7%C3%A3o_Engenheiro_de_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Módulo 5: NumPy - A Matemática dos Vetores**
#
# Link do curso: [clique aqui](https://dascia.academy/)
#
# > **Objetivo:** Computadores não leem textos; eles leem números. Neste módulo, vamos aprender como transformar dados em vetores e usar a biblioteca **NumPy** para realizar cálculos matemáticos ultra-rápidos que são a base de qualquer modelo de IA (RAG, Busca Semântica, Redes Neurais).

# %% [markdown]
# ---
#
# ## **Aula 1: Introdução ao NumPy e Performance**
#
# O Python puro (listas) é ótimo para flexibilidade, mas péssimo para matemática pesada. Ele é lento porque guarda cada número como um "objeto" separado na memória.
#
# O **NumPy** (Numerical Python) resolve isso criando arrays: blocos contíguos de memória, otimizados em C, que permitem fazer cálculos em milhões de dados instantaneamente.

# %% [markdown]
# ### **1.1 Criando Arrays**

# %%
# Importação padrão universal: np


# 1. Array a partir de uma lista

# %%
# 2. Array de Zeros (Muito usado para inicializar pesos de redes neurais)

# %%
# 3. Intervalos (Arange)
# Similar ao range() do Python, mas retorna um array

# %%
# 4. Matrizes (Arrays Multidimensionais)
# Uma matriz 3x3 preenchida com uns

# %%
# 5. Verificando a dimensão dos Tensores

# %% [markdown]
# ### **1.2 Aritmética Vetorial (Broadcasting)**
#
# Aqui está a mágica. Se você quiser multiplicar todos os itens de uma lista por 2 em Python puro, precisaria de um loop `for`. No NumPy, você multiplica o array inteiro de uma vez. O NumPy aplica a operação item a item automaticamente.

# %%
# Aritmética
## Inicializando um array


# Multiplicação por escalar
# O número 2 é "distribuído" para todos os elementos

# Soma com escalar


# Operações entre dois arrays
# [1, 2] * [1, 2] = [1, 4] -> Multiplica posição por posição (Produto de Hadamard)


# Somando os próprios elementos do array
# [1, 2, 3] -> 1 + 2 + 3 -> 6

# %% [markdown]
# ### **1.3 Filtros em Vetores**
#
# Aqui, você consegue aplicar lógica booleana para poder filtrar elementos do vetor.

# %%
# Inicializando um array


# Aplicando lógicas diferentes de filtros

# %% [markdown]
# ### **1.4 O Teste de Performance (A Prova Real)**
#
# Por que usamos NumPy em IA? Vamos simular um processamento de 10 milhões de dados.

# %%
# Importando a biblioteca para mensurar o tempo


# Quantidade de dados: 10 Milhões


# Cria uma lista, percorre elemento por elemento, multiplica por 2 e acumula a soma

# --- Python Puro (Listas) ---


# --- NumPy ---


# Resultados

# %% [markdown]
# > **Nota:** Em IA, onde multiplicamos bilhões de parâmetros, essa diferença de 50x a 100x é a diferença entre treinar um modelo em **dias** ou em **anos**.

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 1)**
#
# **Exercício 1.1: Batch de Preços**
#
# Você tem um array com preços de 5 modelos de IA: `precos = np.array([0.002, 0.05, 0.10, 0.01, 0.03])`.
# Houve um aumento de 10% em todos os serviços. Use NumPy para calcular os novos preços (multiplique por 1.1) e imprima.

# %%
# Escreva seu código aqui

# %% [markdown]
# **Exercício 1.2: Matriz de Zeros e Uns**
#
# Crie uma matriz 4x4 preenchida com zeros. Depois, some 5 a todos os elementos e multiplique por uma matriz 4x1 apenas com uns usando `np.dot()`.
#
# Imprima o resultado da multiplicação e as dimensões da matriz resultante.

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **Aula 2: Vetores e Similaridade (A Alma do RAG)**
#
# Como sabemos se a frase "eu gosto de cachorros" é parecida com "eu amo cães"?
# Para o computador, transformamos frases em **Vetores** (listas de números chamadas *Embeddings*).
#
# Se desenharmos esses vetores num gráfico, frases com significados parecidos apontarão para a mesma direção.

# %% [markdown]
# ### **2.1 A Matemática da Similaridade**
#
# Para medir essa proximidade, usamos a **Similaridade de Cosseno**, definida a partir de operações fundamentais da álgebra linear.
#
# Essa métrica depende de dois componentes:
#
# 1. **Produto Escalar (*dot product*):**
#    Mede o grau de alinhamento entre dois vetores, definido formalmente por
#
#    $$
#    \langle \mathbf{x}, \mathbf{y} \rangle = \sum_{i=1}^{n} x_i\,y_i
#    $$
#
# 2. **Norma (*norm*):**
#    Representa o comprimento (ou magnitude) de um vetor. Na forma geral (norma $L_p$):
#
#    $$
#    \|\mathbf{x}\| = \left(\sum_{i=1}^{n} |x_i|^{p}\right)^{\frac{1}{p}}
#    $$
#
#    No caso mais comum, a **norma euclidiana (L2)**:
#
#    $$
#    \|\mathbf{x}\|_2 = \left({\sum_{i=1}^{n} x_i^2}\right)^{\frac{1}{2}}
#    $$
#
# Se o valor da **similaridade de cosseno** for **1.0**, os vetores são idênticos (mesma direção).
# Se for **0.0**, são ortogonais (sem relação).
# Se for **-1.0**, são opostos (direções contrárias).

# %%
# Vamos imaginar vetores de 2 dimensões para facilitar
# Ex: [Fator "Tecnologia", Fator "Natureza"]

# v1: Alta tecnologia, baixa natureza (ex: "Computador")
v1 = np.array([0.9, 0.1])

# v2: Baixa tecnologia, alta natureza (ex: "Árvore")
v2 = np.array([0.1, 0.9])

# v3: Alta tecnologia, baixa natureza (ex: "Notebook") - Parecido com v1
v3 = np.array([0.8, 0.2])

# %%
# Gráfico dos vetores (ignore o código por enquanto)
import matplotlib.pyplot as plt

# Plot
plt.figure(figsize=(6, 6))

# Vetores como setas
plt.quiver(0, 0, v1[0], v1[1], angles='xy', scale_units='xy', scale=1)
plt.quiver(0, 0, v2[0], v2[1], angles='xy', scale_units='xy', scale=1)
plt.quiver(0, 0, v3[0], v3[1], angles='xy', scale_units='xy', scale=1)

# Labels
plt.text(v1[0] + 0.02, v1[1], 'v1 (Computador)')
plt.text(v2[0] + 0.02, v2[1], 'v2 (Árvore)')
plt.text(v3[0] + 0.02, v3[1], 'v3 (Notebook)')

# Eixos
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.xlabel('Tecnologia')
plt.ylabel('Natureza')
plt.title('Espaço Vetorial e Similaridade')

# Grid e proporção correta
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
# 1. Módulo do vetor, ou norma L2 (Tamanho da seta)
norma_v1 = np.linalg.norm(v1)
norma_v2 = np.linalg.norm(v2)
norma_v3 = np.linalg.norm(v3)
print(f"Tamanho do vetor v1: {norma_v1}")
print(f"Tamanho do vetor v2: {norma_v2}")
print(f"Tamanho do vetor v3: {norma_v3}")

# %%
# 2. Produto Escalar (Dot Product)
dot_product_v1_v2 = np.dot(v1, v2)
dot_product_v1_v3 = np.dot(v1, v3)
dot_product_v2_v3 = np.dot(v2, v3)

print(f"Produto Escalar (v1 . v2): {dot_product_v1_v2}")
print(f"Produto Escalar (v1 . v3): {dot_product_v1_v3}")
print(f"Produto Escalar (v2 . v3): {dot_product_v2_v3}")

# %% [markdown]
# A **Similaridade de Cosseno** deriva diretamente da relação geométrica entre dois vetores:
#
# $$
# \langle \mathbf{x}, \mathbf{y} \rangle
# =
# \|\mathbf{x}\|_2 \, \|\mathbf{y}\|_2 \, \cos(\theta)
# $$
#
# Isolando o cosseno do ângulo $\theta$, obtemos a medida de similaridade:
#
# $$
# \text{Similaridade}(\mathbf{x}, \mathbf{y})
# =
# \cos(\theta)
# =
# \frac{\langle \mathbf{x}, \mathbf{y} \rangle}
# {\|\mathbf{x}\|_2 \, \|\mathbf{y}\|_2}
# $$
#
# Essa métrica mede o **alinhamento direcional** entre os vetores, independentemente de sua magnitude.

# %%
# 3. Similaridade de Cosseno
sim_v1_v2 = dot_product_v1_v2 / (norma_v1 * norma_v2)
sim_v1_v3 = dot_product_v1_v3 / (norma_v1 * norma_v3)
sim_v2_v3 = dot_product_v2_v3 / (norma_v2 * norma_v3)

print(f"Similaridade Computador x Árvore: {sim_v1_v2:.4f}")
print(f"Similaridade Computador x Notebook: {sim_v1_v3:.4f}")
print(f"Similaridade Árvore x Notebook: {sim_v2_v3:.4f}")

# %% [markdown]
# ### **2.2 Distância vs Similaridade**
#
# Às vezes queremos saber a **distância** entre vetores (o quão longe eles estão).
#
# * **Similaridade:** Quanto maior, mais parecidos (máx. 1).
# * **Distância:** Quanto menor, mais parecidos (mín. 0).
#
# A distância baseada na **Similaridade de Cosseno** é definida como:
#
# $$
# \text{Distância}(\mathbf{x}, \mathbf{y})
# =
# 1
# -
# \frac{\langle \mathbf{x}, \mathbf{y} \rangle}
# {\|\mathbf{x}\|_2 \, \|\mathbf{y}\|_2}
# $$

# %%
# Distância de Cosseno
dist_v1_v2 = 1 - sim_v1_v2
dist_v1_v3 = 1 - sim_v1_v3
dist_v2_v3 = 1 - sim_v2_v3

print(f"Distância Computador x Árvore: {dist_v1_v2:.4f}")
print(f"Distância Computador x Notebook: {dist_v1_v3:.4f}")
print(f"Distância Árvore x Notebook: {dist_v2_v3:.4f}")

# %%
# Convertendo para ângulo

# np.arccos retorna o ângulo em radianos
theta_rad = np.arccos(sim_v1_v2)

# np.degrees transforma rad em graus
theta_graus = np.degrees(theta_rad)

print(f"Ângulo entre Computador e Árvore: {theta_graus:.1f} graus")
# Note: Vetores ortogonais (90 graus) têm similaridade 0.

# %% [markdown]
# ### 🧠 **Exercícios de Fixação (Aula 2)**
#
# **Exercício 2.1: Calculadora de Embeddings Manual**
#
# Dados dois vetores simples: `A = np.array([1, 0, 1])` e `B = np.array([0, 1, 1])`.
# Calcule a similaridade de cosseno entre eles passo a passo (calcule o dot, calcule as normas e divida).

# %%
# Escreva seu código aqui

# %% [markdown]
# **Exercício 2.2: O Motor de Busca Miniatura**
#
# Você tem o vetor de busca `query = np.array([1, 1])`.
# Você tem uma lista de documentos (vetores):
#
# * `docA = np.array([1, 0.9])`
# * `docB = np.array([0.1, 0])`
# Calcule qual documento é mais similar à query usando `np.dot` (pode ignorar a norma neste exercício simples, assumindo que são unitários).

# %%
# Escreva seu código aqui

# %% [markdown]
# ---
#
# ## **🚀 Próximo Passo: Projeto no Cursor**
#
# Agora você entende a matemática que faz o ChatGPT encontrar respostas nos seus documentos.
#
# **Vamos para a IDE Cursor construir o "Simple Vector Store".**
#
# Neste projeto, você não vai usar bibliotecas prontas de vetores (como ChromaDB ou Pinecone). Você vai **construir a sua própria**.
#
# * Você criará uma classe `VectorStore` que guarda documentos e vetores na memória.
# * Você implementará o método `query` que recebe uma pergunta (vetor), varre todos os documentos, calcula o cosseno de cada um e retorna os "Top K" mais parecidos.
# * É a engenharia pura por trás do RAG (Retrieval Augmented Generation).
#
# Prepare seu NumPy e vamos para o Cursor!
